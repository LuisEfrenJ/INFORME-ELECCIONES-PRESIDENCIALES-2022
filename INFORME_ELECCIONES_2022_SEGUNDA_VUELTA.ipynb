# %% [markdown]
# # INFORME ELECCIONES 2022 SEGUNDA VUELTA

# %%
import matplotlib.pyplot as plt
"Resumen de los resultados finales en segunda vuelta 2022"
etiquetas=["Gustavo Petro","Rodolfo Hernández"]
valores=[50.44,47.31]
colores=["cyan","yellow"]

plt.pie(x=valores,labels=etiquetas,colors=colores,autopct="%1.2f%%")
plt.title("Resultados Finales de Elecciones Segunda Vuelta 2022 en General")
plt.show()

# %% [markdown]
# https://www.larepublica.co/elecciones-presidenciales-2022/resultados-segunda-vuelta

# %%
import matplotlib.pyplot as plt 
#INFORMACION GENERAL ELECCIONES PRESIDENCIALES 2022
etiquetas = ["No Marcados","A Candidatos", "Nulos", "Validos", "En Blanco"]
valores = [23613,21861425, 271667, 22363412, 501785]
colores =["darkred", "pink", "coral", "teal", "salmon"]
plt.pie(x=valores, labels=etiquetas, colors= colores, autopct='%1.2f%%')
plt.title ("CONTEO DE VOTACIONES")
plt.show()

# %% [markdown]
# # DATOS RESTANTES:
# Mesas Informadas 103.364 de 103.364
# Votantes 22.658.694 de 39.002.239

# %% [markdown]
# https://www.eltiempo.com/elecciones-2022/presidencia/resultados-elecciones-en-colombia-2022-en-vivo-boletines-registraduria-681350

# %%
import matplotlib.pyplot as plt
#Distribucion de departamentos a favor del Pacto Historico
eje_x = ["Amazonas", "Atlantico", "Bogota","Bolivar", "Cauca", "Cesar" , "Choco","Cordoba", "Guainia","La Guajira", "Magdalena","Nariño","Putumayo" ,"San Andres", "Sucre","Valle", "Vaupes"] 
eje_y = [ 12883 , 672832, 2253997,493041,515074, 250499,127846,437016, 6536, 162849, 302439,592170,110118, 8545, 262135, 1310236, 6447 ]
plt.barh(eje_x,eje_y, color="cyan")
plt.ylabel("Departamentos")
plt.xlabel("Numero De Votaciones")
plt.title("Departamentos A Favor Del Partido Coalición Pacto Historico-Gustavo Petro, Francia Márquez")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# https://www.larepublica.co/elecciones-presidenciales-2022/resultados-segunda-vuelta

# %%
import matplotlib.pyplot as plt
#Departamentos a favor del Partido Liga De Gobernantes Anticorrupcion a cargo de Rodoldo Hernández-Marelen Castillo
eje_x = ["Antioquia","Arauca", "Boyaca", "Caldas", "Caqueta", " CASANARE","Consulados", "Cundinamarca","Guaviare", "Huila", "Meta","Norte De Santander", "Quindio","Risaralda","Santander" , "Tolima","Vichada" ] 
eje_y = [ 1822700 , 69473 , 378899,267988, 88922,  143796 , 185557, 756454, 17601, 305799,307137, 557406, 151653,  238963,871291, 388640,11447 ]

plt.barh(eje_x,eje_y, color="yellow")
plt.ylabel("Departamento")
plt.xlabel("Numero De Votaciones")
plt.title("Departamentos A Favort Del Partido Liga De Gobernantes Anticorrupcion")
plt.show
# Out:
# <function matplotlib.pyplot.show>
